# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshkpraj/Neural_Networks/blob/main/upgraded_NN_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#creating model class
import torch
import torch.nn as nn

class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()

    self.linear=nn.Linear(num_features,1)
    self.Sigmoid=nn.Sigmoid()


  def forward(self,features):
    out=self.linear(features)
    out=self.Sigmoid(out)
    return out

# %%
#creating dataset

features= torch.rand(50,5)

#model creation
model=Model(features.shape[1])

#call model for forward pass(model.forward(features))
model(features)
# Out:
# tensor([[0.5615],
#         [0.5641],
#         [0.5401],
#         [0.4676],
#         [0.5342],
#         [0.4869],
#         [0.5184],
#         [0.4953],
#         [0.6049],
#         [0.5497],
#         [0.5437],
#         [0.5356],
#         [0.5300],
#         [0.5664],
#         [0.5116],
#         [0.5526],
#         [0.5298],
#         [0.5684],
#         [0.5356],
#         [0.4960],
#         [0.5019],
#         [0.5449],
#         [0.5449],
#         [0.5418],
#         [0.5038],
#         [0.5035],
#         [0.5040],
#         [0.5570],
#         [0.5163],
#         [0.5249],
#         [0.5222],
#         [0.5795],
#         [0.4902],
#         [0.5651],
#         [0.5234],
#         [0.5360],
#         [0.4847],
#         [0.5818],
#         [0.5346],
#         [0.5155],
#         [0.4963],
#         [0.5125],
#         [0.5468],
#         [0.5069],
#         [0.5189],
#         [0.5214],
#         [0.4943],
#         [0.5863],
#         [0.5157],
# ...

# %%
#display model weights and bias
# !pip install torchinfo

# %%
from torchinfo import summary
summary(model,input_size=(50,5))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Model                                    [50, 1]                   --
# ├─Linear: 1-1                            [50, 1]                   6
# ├─Sigmoid: 1-2                           [50, 1]                   --
# ...
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ...
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ...
